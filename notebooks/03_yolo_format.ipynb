# %%
import geopandas as gpd

# %%
tiles = gpd.read_file("/Users/saharmohamed/Documents/UBS_Material/DL4CV/dl4cv-object-detection-on-aerial-imagery/data/tiles.geojson")
trees_data = gpd.read_file("/Users/saharmohamed/Documents/UBS_Material/DL4CV/dl4cv-object-detection-on-aerial-imagery/data/trees_box.geojson")

# %%
tiles
# Out:
#                                id                                  title  \
# 0    Tile(x=6773, y=293571, z=19)  XYZ tile Tile(x=6773, y=293571, z=19)
# 1    Tile(x=6773, y=293572, z=19)  XYZ tile Tile(x=6773, y=293572, z=19)
# 2    Tile(x=6773, y=293573, z=19)  XYZ tile Tile(x=6773, y=293573, z=19)
# 3    Tile(x=6773, y=293574, z=19)  XYZ tile Tile(x=6773, y=293574, z=19)
# 4    Tile(x=6773, y=293575, z=19)  XYZ tile Tile(x=6773, y=293575, z=19)
# ..                            ...                                    ...
# 546  Tile(x=6791, y=293595, z=19)  XYZ tile Tile(x=6791, y=293595, z=19)
# 547  Tile(x=6791, y=293596, z=19)  XYZ tile Tile(x=6791, y=293596, z=19)
# 548  Tile(x=6791, y=293597, z=19)  XYZ tile Tile(x=6791, y=293597, z=19)
# 549  Tile(x=6791, y=293598, z=19)  XYZ tile Tile(x=6791, y=293598, z=19)
# 550  Tile(x=6791, y=293599, z=19)  XYZ tile Tile(x=6791, y=293599, z=19)
#
#                                               geometry
# ...

# %%
trees_data
# Out:
#            osm_id natural           species species_mapped           lon  \
# 0      5269771172    tree  Mangifera indica          Mango -1.951858e+07
# 1      5269771173    tree  Mangifera indica          Mango -1.951861e+07
# 2      5269771174    tree  Mangifera indica          Mango -1.951861e+07
# 3      5269771175    tree  Mangifera indica          Mango -1.951860e+07
# 4      5269771176    tree  Mangifera indica          Mango -1.951860e+07
# ...           ...     ...               ...            ...           ...
# 10626  5322704745    tree    Cocos nucifera        Coconut -1.951967e+07
# 10627  5322704746    tree    Cocos nucifera        Coconut -1.951964e+07
# 10628  5322704747    tree    Cocos nucifera        Coconut -1.951963e+07
# 10629  5322704748    tree    Cocos nucifera        Coconut -1.951964e+07
# 10630  5322704749    tree    Cocos nucifera        Coconut -1.951965e+07
#
#                 lat                                           geometry
# ...

# %%
from geomltoolkits.utils import split_geojson_by_tiles


# Split GeoJSON by tiles
split_geojson_by_tiles(tiles, trees_data, output_dir="/Users/saharmohamed/Documents/UBS_Material/DL4CV/dl4cv-object-detection-on-aerial-imagery/data/labels")

# %%
print(tiles.crs)
print(trees_data.crs)
# Out:
# EPSG:4326
# EPSG:3857

# %%
trees_data = trees_data.to_crs(tiles.crs)
trees_data
# Out:
#            osm_id natural           species species_mapped           lon  \
# 0      5269771172    tree  Mangifera indica          Mango -1.951858e+07
# 1      5269771173    tree  Mangifera indica          Mango -1.951861e+07
# 2      5269771174    tree  Mangifera indica          Mango -1.951861e+07
# 3      5269771175    tree  Mangifera indica          Mango -1.951860e+07
# 4      5269771176    tree  Mangifera indica          Mango -1.951860e+07
# ...           ...     ...               ...            ...           ...
# 10626  5322704745    tree    Cocos nucifera        Coconut -1.951967e+07
# 10627  5322704746    tree    Cocos nucifera        Coconut -1.951964e+07
# 10628  5322704747    tree    Cocos nucifera        Coconut -1.951963e+07
# 10629  5322704748    tree    Cocos nucifera        Coconut -1.951964e+07
# 10630  5322704749    tree    Cocos nucifera        Coconut -1.951965e+07
#
#                 lat                                           geometry
# ...

# %%
tiles.columns
# Out:
# Index(['id', 'title', 'geometry'], dtype='object')

# %%
tiles_path = "tiles.geojson"
trees_path = "trees.geojson"

tiles.to_file(tiles_path, driver="GeoJSON")
trees_data.to_file(trees_path, driver="GeoJSON")

# %%
from geomltoolkits.utils import split_geojson_by_tiles

# %%
for feature in data["features"]:
    pid = feature.get("properties", {}).get("id")

    if pid is None:
        raise ValueError("Feature missing properties['id']")

    # add top-level id
    feature["id"] = pid

# %%
with open("tiles_with_feature_id.geojson", "w", encoding="utf-8") as f:
    json.dump(data, f)

# %%
with open("tiles_with_feature_id.geojson") as f:
    d = json.load(f)

print(d["features"][0].keys())
# Out:
# dict_keys(['type', 'properties', 'geometry', 'id'])

# %%
import json

with open("tiles_with_id.geojson") as f:
    data = json.load(f)

print(data["features"][0]["properties"]["id"])
# Out:
# Tile(x=6773, y=293571, z=19)

# %%
tiles[["id", "title"]].head()
# Out:
#                              id                                  title
# 0  Tile(x=6773, y=293571, z=19)  XYZ tile Tile(x=6773, y=293571, z=19)
# 1  Tile(x=6773, y=293572, z=19)  XYZ tile Tile(x=6773, y=293572, z=19)
# 2  Tile(x=6773, y=293573, z=19)  XYZ tile Tile(x=6773, y=293573, z=19)
# 3  Tile(x=6773, y=293574, z=19)  XYZ tile Tile(x=6773, y=293574, z=19)
# 4  Tile(x=6773, y=293575, z=19)  XYZ tile Tile(x=6773, y=293575, z=19)

# %%
import json
with open("tiles.geojson") as f:
    data = json.load(f)

print(data["features"][0]["properties"].keys())

tile_id = data["features"][0]["properties"].get("id", data["features"][0]["properties"]["id"])
print(tile_id)
# Out:
# dict_keys(['id', 'title'])
# Tile(x=6773, y=293571, z=19)

# %%
split_geojson_by_tiles(
    mother_geojson_path="trees.geojson",
    children_geojson_path="tiles_with_feature_id.geojson",
    output_dir="labels"
)

# %%
tiles
# Out:
#                                id                                  title  \
# 0    Tile(x=6773, y=293571, z=19)  XYZ tile Tile(x=6773, y=293571, z=19)
# 1    Tile(x=6773, y=293572, z=19)  XYZ tile Tile(x=6773, y=293572, z=19)
# 2    Tile(x=6773, y=293573, z=19)  XYZ tile Tile(x=6773, y=293573, z=19)
# 3    Tile(x=6773, y=293574, z=19)  XYZ tile Tile(x=6773, y=293574, z=19)
# 4    Tile(x=6773, y=293575, z=19)  XYZ tile Tile(x=6773, y=293575, z=19)
# ..                            ...                                    ...
# 546  Tile(x=6791, y=293595, z=19)  XYZ tile Tile(x=6791, y=293595, z=19)
# 547  Tile(x=6791, y=293596, z=19)  XYZ tile Tile(x=6791, y=293596, z=19)
# 548  Tile(x=6791, y=293597, z=19)  XYZ tile Tile(x=6791, y=293597, z=19)
# 549  Tile(x=6791, y=293598, z=19)  XYZ tile Tile(x=6791, y=293598, z=19)
# 550  Tile(x=6791, y=293599, z=19)  XYZ tile Tile(x=6791, y=293599, z=19)
#
#                                               geometry
# ...
